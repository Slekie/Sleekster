# %%
# Install required packages (run once). If your environment already has them, you can skip.
import sys
# !{sys.executable} -m pip install --upgrade pip setuptools wheel
# !{sys.executable} -m pip install --quiet numpy pandas matplotlib pillow ffmpeg-python
# !{sys.executable} -m pip install --quiet "stable-baselines3==2.3.0" "gymnasium==0.29.1" "shimmy==0.2.1" torch tensorboard
# Out:
# Requirement already satisfied: pip in c:\users\slick\desktop\ml\env\lib\site-packages (25.3)
# Requirement already satisfied: setuptools in c:\users\slick\desktop\ml\env\lib\site-packages (80.9.0)
# Requirement already satisfied: wheel in c:\users\slick\desktop\ml\env\lib\site-packages (0.45.1)

# %%
# Imports
import os
import glob
import json
import time
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gymnasium as gym
from gymnasium import spaces

# stable-baselines3 + wrappers
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# optional: stable-baselines3 env checker
try:
    from stable_baselines3.common.env_checker import check_env as sb3_check_env
except Exception:
    sb3_check_env = None
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
# Configuration (edit to taste)
DATA_DIR = os.path.join("data", "multiasset")   # where Notebook 01 saved *_normalized.csv and asset_to_idx.csv
MODEL_DIR = os.path.join("models", "multiasset")
os.makedirs(MODEL_DIR, exist_ok=True)

WINDOW = 50
TRAIN_EPISODES = 50
TOTAL_TIMESTEPS = TRAIN_EPISODES * 10_000  # used for model.learn()
N_ENVS = 4
EMBED_DIM = 8

EMBED_FILE = os.path.join(MODEL_DIR, "asset_embeddings.npy")
ASSET_MAP_FILE = os.path.join(DATA_DIR, "asset_to_idx.csv")

MODEL_FILE = os.path.join(MODEL_DIR, "ppo_multiasset.zip")
VEC_FILE = os.path.join(MODEL_DIR, "vec_normalize.pkl")
METRICS_FILE = os.path.join(MODEL_DIR, "eval_metrics.json")

# PPO params (change as needed)
PPO_PARAMS = dict(
    policy="MlpPolicy",
    verbose=1,
    learning_rate=3e-4,
    batch_size=256,
    n_epochs=10,
    ent_coef=0.01
)

# %%
# Load normalized CSVs created by Notebook 01
def load_normalized_datasets(data_dir, window=WINDOW):
    csv_files = sorted(glob.glob(os.path.join(data_dir, "*_normalized.csv")))
    if not csv_files:
        raise FileNotFoundError(f"No normalized CSVs found in {data_dir}. Run Notebook 01 first.")
    datasets = {}
    for p in csv_files:
        safe = os.path.basename(p).replace("_normalized.csv","")
        df = pd.read_csv(p, index_col=0, parse_dates=True)
        # required columns
        required = ['o_pc','h_pc','l_pc','c_pc','v_pc','Close_raw']
        if not all(c in df.columns for c in required):
            # try auto-convert if raw fields exist
            if all(c in df.columns for c in ['open','high','low','close','volume']):
                tmp = df.copy()
                tmp['o_pc'] = tmp['open'].pct_change()
                tmp['h_pc'] = tmp['high'].pct_change()
                tmp['l_pc'] = tmp['low'].pct_change()
                tmp['c_pc'] = tmp['close'].pct_change()
                tmp['v_pc'] = tmp['volume'].pct_change()
                tmp['Close_raw'] = tmp['close']
                tmp = tmp.dropna()
                df = tmp[required]
            else:
                raise ValueError(f"{p} missing required columns and cannot be auto-converted.")
        else:
            df = df[required].dropna()
        if len(df) > window:
            datasets[safe] = df
    if not datasets:
        raise ValueError("No datasets passed the minimum length requirement.")
    print(f"Loaded {len(datasets)} datasets from {data_dir}")
    return datasets

# Example:
datasets = load_normalized_datasets(DATA_DIR, WINDOW)
# Out:
# Loaded 16 datasets from data\multiasset

# %%
def load_asset_map_and_embeddings(datasets, asset_map_file=ASSET_MAP_FILE, embed_file=EMBED_FILE, embed_dim=EMBED_DIM):
    """
    Ensures asset->index ordering matches `datasets` keys.
    If asset_map_file exists it will be used, otherwise it creates one from datasets order.
    Loads embeddings if present and matches order; otherwise creates random embeddings matching order and saves them.
    Returns (embeddings ndarray shape (n_assets, embed_dim), asset_to_idx dict)
    """
    # use datasets order as canonical order
    safe_names = list(datasets.keys())
    # try to load existing map; prefer file only if keys match dataset keys
    asset_to_idx = {s:i for i,s in enumerate(safe_names)}
    if os.path.exists(asset_map_file):
        try:
            df_map = pd.read_csv(asset_map_file, index_col=0, squeeze=True)
            # df_map may be a series mapping safe->idx
            loaded_map = df_map.to_dict() if hasattr(df_map, "to_dict") else dict(df_map)
            # compare sets
            if set(loaded_map.keys()) == set(safe_names):
                asset_to_idx = {k:int(loaded_map[k]) for k in safe_names}
            else:
                # override file to match current datasets order
                pd.Series({s:i for i,s in enumerate(safe_names)}).to_csv(asset_map_file)
                asset_to_idx = {s:i for i,s in enumerate(safe_names)}
        except Exception:
            pd.Series({s:i for i,s in enumerate(safe_names)}).to_csv(asset_map_file)
            asset_to_idx = {s:i for i,s in enumerate(safe_names)}
    else:
        # create the file
        pd.Series({s:i for i,s in enumerate(safe_names)}).to_csv(asset_map_file)
        asset_to_idx = {s:i for i,s in enumerate(safe_names)}

    n_assets = len(asset_to_idx)
    # load embeddings if present and compatible
    if os.path.exists(embed_file):
        emb = np.load(embed_file)
        if emb.shape[0] != n_assets or emb.shape[1] < 1:
            # mismatch → recreate aligned embeddings
            emb = np.random.randn(n_assets, embed_dim).astype(np.float32)
            np.save(embed_file, emb)
            print("Embedding file mismatch; recreated embeddings to match dataset order.")
    else:
        emb = np.random.randn(n_assets, embed_dim).astype(np.float32)
        np.save(embed_file, emb)
        print(f"Created new embeddings: {embed_file}")

    # ensure dtype
    emb = emb.astype(np.float32)
    print(f"Loaded embeddings for {n_assets} assets (dim={emb.shape[1]})")
    return emb, asset_to_idx

# Example:
embeddings, asset_map = load_asset_map_and_embeddings(datasets)
# Out:
# Loaded embeddings for 16 assets (dim=8)

# %% [markdown]
# import gym
# import numpy as np
# from gym import spaces
#
# class MultiAssetEnv(gym.Env):
#     """
#     MultiAssetEnv:
#     - datasets: dict safe_name -> dataframe with columns [o_pc,h_pc,l_pc,c_pc,v_pc,Close_raw]
#     - asset_to_idx: dict safe_name->index
#     - embeddings: ndarray (n_assets, embed_dim)
#     Observation: (window, 5 + 1 + embed_dim)  -> features, balance, embedding per timestep
#     Action space: Discrete(3): 0 hold, 1 buy, 2 sell
#     """
#
#     metadata = {'render.modes': ['human']}
#
#     def __init__(self, datasets, asset_to_idx, embeddings, window=WINDOW, initial_balance=10_000, risk=0.02, leverage=100):
#         super().__init__()
#         self.datasets = datasets
#         self.asset_to_idx = asset_to_idx
#         self.embeddings = embeddings
#         self.window = window
#         self.initial_balance = initial_balance
#         self.risk = risk
#         self.leverage = leverage
#
#         self.safe_names = list(self.datasets.keys())
#         self.n_assets = len(self.safe_names)
#         self.asset_idx = 0
#         self.current_safe = self.safe_names[self.asset_idx]
#         self.data = self.datasets[self.current_safe]
#         self.ptr = self.window
#         self.balance = self.initial_balance
#         self.position = 0
#
#         self.embed_dim = self.embeddings.shape[1] if self.embeddings is not None else 0
#         n_features = 5
#         obs_dim = n_features + 1 + self.embed_dim
#         self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window, obs_dim), dtype=np.float32)
#         self.action_space = spaces.Discrete(3)
#
#         # RNG
#         self.np_random = None
#         self.seed(None)
#
#         # trackers for render (per symbol)
#         self.prices = {s:[] for s in self.safe_names}
#         self.actions = {s:[] for s in self.safe_names}
#
#     def seed(self, seed=None):
#         self.np_random, seed = gym.utils.seeding.np_random(seed)
#         return [seed]
#
#     def reset(self, seed=None, options=None):
#         if seed is not None:
#             self.seed(seed)
#         self.asset_idx = int(self.np_random.integers(0, self.n_assets))
#         self.current_safe = self.safe_names[self.asset_idx]
#         self.data = self.datasets[self.current_safe]
#         self.ptr = self.window
#         self.balance = self.initial_balance
#         self.position = 0
#
#         # initialize trackers with the initial window close prices
#         init_prices = list(self.data['Close_raw'].iloc[self.ptr-self.window:self.ptr].values)
#         self.prices[self.current_safe] = init_prices.copy()
#         self.actions[self.current_safe] = [0]*len(init_prices)
#         return self._get_obs(), {}
#
#     def _get_obs(self):
#         window_data = self.data.iloc[self.ptr-self.window:self.ptr]
#         feat = window_data[['o_pc','h_pc','l_pc','c_pc','v_pc']].values.astype(np.float32)
#         balance_col = np.full((self.window,1), float(self.balance)/float(self.initial_balance), dtype=np.float32)
#         emb = np.zeros((self.window, self.embed_dim), dtype=np.float32)
#         idx = self.asset_idx
#         if self.embeddings is not None and idx < self.embeddings.shape[0]:
#             emb = np.tile(self.embeddings[idx].reshape(1,-1).astype(np.float32), (self.window, 1))
#         obs = np.concatenate([feat, balance_col, emb], axis=1)
#         return obs
#
#     def step(self, action):
#         prev_close = float(self.data['Close_raw'].iloc[self.ptr-1])
#         new_close = float(self.data['Close_raw'].iloc[self.ptr])
#
#         if action == 1:
#             self.position = 1
#         elif action == 2:
#             self.position = -1
#         else:
#             self.position = 0
#
#         pnl = (new_close - prev_close)/prev_close * self.position * self.leverage
#         self.balance *= (1.0 + pnl * self.risk)
#         reward = float(pnl)
#
#         # record
#         safe = self.current_safe
#         self.prices[safe].append(new_close)
#         self.actions[safe].append(int(action))
#
#         self.ptr += 1
#         done = self.ptr >= len(self.data)
#         info = {'balance': self.balance, 'asset': safe}
#         return self._get_obs(), reward, done, False, info
#
#     def render(self, mode='human', animate=False, interval=200, save_path=None, fps=10):
#         import matplotlib.animation as animation
#         assets_with_data = [s for s in self.safe_names if len(self.prices.get(s,[]))>0]
#         if not assets_with_data:
#             print("⚠️ Nothing recorded to render yet.")
#             return
#         n = len(assets_with_data)
#         fig, axes = plt.subplots(n,1, figsize=(10,4*n), sharex=True)
#         if n==1:
#             axes=[axes]
#         if not animate:
#             for i,s in enumerate(assets_with_data):
#                 prices = np.array(self.prices[s])
#                 acts = np.array(self.actions[s])
#                 steps = np.arange(len(prices))
#                 axes[i].plot(steps, prices, label=f"{s} price")
#                 axes[i].scatter(steps[acts==1], prices[acts==1], marker='^', color='green', label='Buy')
#                 axes[i].scatter(steps[acts==2], prices[acts==2], marker='v', color='red', label='Sell')
#                 axes[i].legend(); axes[i].grid(True)
#             plt.tight_layout()
#             if save_path and save_path.lower().endswith(('.png','.jpg','.pdf')):
#                 plt.savefig(save_path, dpi=200); print("Saved static render to", save_path)
#             plt.show()
#             return
#
#         # Animated rendering
#         lines, buys, sells = [], [], []
#         for ax, s in zip(axes, assets_with_data):
#             line, = ax.plot([],[],lw=2)
#             buy_sc = ax.scatter([],[], marker='^', color='green')
#             sell_sc = ax.scatter([],[], marker='v', color='red')
#             lines.append(line); buys.append(buy_sc); sells.append(sell_sc)
#             arr = np.array(self.prices[s])
#             ax.set_xlim(0, max(1,len(arr)))
#             ax.set_ylim(np.min(arr)*0.98, np.max(arr)*1.02)
#             ax.set_title(s)
#             ax.grid(True)
#
#         def update(frame):
#             artists=[]
#             for i,s in enumerate(assets_with_data):
#                 pr = np.array(self.prices[s]); ac = np.array(self.actions[s])
#                 if frame>len(pr): f = len(pr)
#                 else: f = frame
#                 x = np.arange(f); y = pr[:f]
#                 lines[i].set_data(x,y); artists.append(lines[i])
#                 buys_idx = x[ac[:f]==1] if f>0 else []
#                 sells_idx = x[ac[:f]==2] if f>0 else []
#                 if len(buys_idx)>0:
#                     buys[i].set_offsets(np.c_[buys_idx, pr[:f][ac[:f]==1]])
#                 else:
#                     buys[i].set_offsets([])
#                 if len(sells_idx)>0:
#                     sells[i].set_offsets(np.c_[sells_idx, pr[:f][ac[:f]==2]])
#                 else:
#                     sells[i].set_offsets([])
#                 artists += [buys[i], sells[i]]
#             return artists
#
#         frames = len(self.prices[assets_with_data[0]])
#         ani = animation.FuncAnimation(fig, update, frames=frames, interval=interval, blit=True, repeat=False)
#         if save_path:
#             ext = os.path.splitext(save_path)[1].lower()
#             if ext=='.mp4':
#                 ani.save(save_path, writer='ffmpeg', fps=fps)
#             elif ext=='.gif':
#                 ani.save(save_path, writer='pillow', fps=fps)
#             print("Saved animation to", save_path)
#         plt.show()

# %%
class MultiAssetEnv(gym.Env):
    def __init__(
        self,
        datasets,
        asset_map,
        embeddings,
        window=50,
        initial_balance=10000,
        risk=0.02,
        leverage=100
    ):
        super().__init__()

        self.datasets = datasets
        self.asset_map = asset_map              # NEW
        self.embeddings = embeddings            # NEW
        self.window = window
        self.initial_balance = initial_balance
        self.risk = risk
        self.leverage = leverage

        self.asset_idx = 0
        self.data = self.datasets[list(self.datasets.keys())[self.asset_idx]]
        self.ptr = self.window
        self.balance = self.initial_balance
        self.position = 0

        # Add embedding_dim to observations
        emb_dim = self.embeddings.shape[1]

        n_features = 5 + emb_dim    # price features + embedding
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf,
            shape=(window, n_features),
            dtype=np.float32
        )

        self.action_space = spaces.Discrete(3)

# %%
def make_env_factory(datasets, asset_to_idx, embeddings, window=WINDOW):
    def _init():
        return MultiAssetEnv(datasets, asset_to_idx, embeddings, window=window)
    return _init

# %%
def train_and_save(datasets, asset_map, embeddings, model_dir=MODEL_DIR, total_timesteps=TOTAL_TIMESTEPS, n_envs=N_ENVS):
    os.makedirs(model_dir, exist_ok=True)
    env_fns = [make_env_factory(datasets, asset_map, embeddings, WINDOW) for _ in range(n_envs)]
    vec_env = DummyVecEnv(env_fns)
    vec_env = VecNormalize(vec_env, norm_obs=True, norm_reward=False, clip_obs=10.)

    model = PPO(**PPO_PARAMS, env=vec_env, tensorboard_log=os.path.join(model_dir,"tensorboard"))
    print("Starting training for", total_timesteps, "timesteps...")
    model.learn(total_timesteps=total_timesteps)
    model.save(MODEL_FILE)
    vec_env.save(VEC_FILE)
    print("Saved model ->", MODEL_FILE)
    return model, vec_env

# %%
def evaluate_model(model_path, datasets, n_episodes=10, window=WINDOW):
    model = PPO.load(model_path)

    # Dummy embeddings in case actual ones were not saved
    emb_dummy = np.zeros((len(datasets), EMBED_DIM), dtype=np.float32)
    asset_map = {s: i for i, s in enumerate(datasets.keys())}

    env = MultiAssetEnv(
        datasets=datasets,
        asset_map=asset_map,
        embeddings=emb_dummy,
        window=window
    )

    rewards = []

    for ep in range(n_episodes):
        obs, _ = env.reset()
        done = False
        ep_r = 0.0

        while not done:
            action, _ = model.predict(obs, deterministic=True)

            # --- FIXED ACTION CONVERSION ---
            if isinstance(action, (np.integer, int)):
                act = int(action)
            else:
                act = int(np.array(action).flatten()[0])
            # --------------------------------

            obs, reward, done, truncated, info = env.step(act)
            ep_r += float(reward)

        rewards.append(ep_r)

    metrics = {
        "n_episodes": n_episodes,
        "mean_reward": float(np.mean(rewards)),
        "std_reward": float(np.std(rewards)),
        "total_reward": float(np.sum(rewards)),
        "timestamp": datetime.utcnow().isoformat()
    }

    with open(METRICS_FILE, "w") as fh:
        json.dump(metrics, fh, indent=2)

    print("Evaluation metrics:", metrics)
    return metrics

# %%
# Main pipeline
datasets = load_normalized_datasets(DATA_DIR, WINDOW)
embeddings, asset_map = load_asset_map_and_embeddings(datasets)

# Train
model, vec_env = train_and_save(datasets, asset_map, embeddings, MODEL_DIR, TOTAL_TIMESTEPS, N_ENVS)

# Evaluate
metrics = evaluate_model(MODEL_FILE, datasets, n_episodes=10, window=WINDOW)
print("Done. Metrics:", metrics)
# Out:
# Loaded 16 datasets from data\multiasset
# Loaded embeddings for 16 assets (dim=8)
# Using cpu device
# C:\users\slick\Desktop\ml\env\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Starting training for 500000 timesteps...
# Logging to models\multiasset\tensorboard\PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 506  |
# |    iterations      | 1    |
# |    time_elapsed    | 16   |
# |    total_timesteps | 8192 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 2           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009282675 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.052509964 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.594       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 1.44        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 427        |
# |    iterations           | 3          |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00965514 |
# |    clip_fraction        | 0.0851     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.09739107 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.558      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0183    |
# |    value_loss           | 1.44       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 431         |
# |    iterations           | 4           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009311359 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.056494415 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.42        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 1.2         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 5           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010089372 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.053806305 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.645       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 1.58        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 6            |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0112773925 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.037742674  |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.504        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.03        |
# |    value_loss           | 1.3          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 7           |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.01189932  |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.019932866 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.527       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 1.33        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 8            |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.012596805  |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.038912416 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.684        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0329      |
# |    value_loss           | 1.56         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 9            |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.012975686  |
# |    clip_fraction        | 0.151        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.053851485 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.842        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0322      |
# |    value_loss           | 1.57         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 10           |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.011243731  |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -0.019945383 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.645        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0312      |
# |    value_loss           | 1.4          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 11           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.015245681  |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.997       |
# |    explained_variance   | -0.023408294 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.559        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0375      |
# |    value_loss           | 1.23         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 12          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013959081 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.08620465  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.649       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 1.39        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 433         |
# |    iterations           | 13          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013967646 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.978      |
# |    explained_variance   | 0.04205978  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.52        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0333     |
# |    value_loss           | 1.47        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 14           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.013733583  |
# |    clip_fraction        | 0.16         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.964       |
# |    explained_variance   | -0.051074386 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.831        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0349      |
# |    value_loss           | 1.73         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 430         |
# |    iterations           | 15          |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.012864916 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | -0.01098907 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.755       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0326     |
# |    value_loss           | 1.68        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 428        |
# |    iterations           | 16         |
# |    time_elapsed         | 305        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.01669043 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.953     |
# |    explained_variance   | 0.08001983 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.686      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0337    |
# |    value_loss           | 1.46       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 17          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.014700033 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.949      |
# |    explained_variance   | 0.0316301   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.747       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0341     |
# |    value_loss           | 1.69        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 18           |
# |    time_elapsed         | 351          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.016987719  |
# |    clip_fraction        | 0.176        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.932       |
# |    explained_variance   | -0.105008245 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.816        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0357      |
# |    value_loss           | 1.79         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 19           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.016397327  |
# |    clip_fraction        | 0.182        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | -0.018525243 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.949        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.032       |
# |    value_loss           | 1.74         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 20           |
# |    time_elapsed         | 396          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.018207174  |
# |    clip_fraction        | 0.185        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.922       |
# |    explained_variance   | 0.0010103583 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.532        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0341      |
# |    value_loss           | 1.86         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 21           |
# |    time_elapsed         | 416          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.014626486  |
# |    clip_fraction        | 0.152        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.913       |
# |    explained_variance   | -0.019938827 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.721        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0329      |
# |    value_loss           | 1.82         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 414        |
# |    iterations           | 22         |
# |    time_elapsed         | 435        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.01634233 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.919     |
# |    explained_variance   | 0.09887308 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.819      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0326    |
# |    value_loss           | 1.51       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 23          |
# |    time_elapsed         | 454         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.018151548 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | 0.02504921  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.669       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0328     |
# |    value_loss           | 1.69        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 24          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.016390989 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.086049914 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.65        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0308     |
# |    value_loss           | 1.34        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 25          |
# |    time_elapsed         | 492         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.018197127 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.903      |
# |    explained_variance   | -0.12308204 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.728       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0328     |
# |    value_loss           | 1.48        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 26          |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.017836614 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | -0.07198441 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.613       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0357     |
# |    value_loss           | 1.55        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 27           |
# |    time_elapsed         | 528          |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.017276028  |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.89        |
# |    explained_variance   | -0.017243743 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.674        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0338      |
# |    value_loss           | 1.52         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 28          |
# |    time_elapsed         | 548         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.01726057  |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.891      |
# |    explained_variance   | -0.04910779 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.653       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0312     |
# |    value_loss           | 1.56        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 419         |
# |    iterations           | 29          |
# |    time_elapsed         | 566         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.018745271 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | -0.11214054 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.565       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0323     |
# |    value_loss           | 1.48        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 419          |
# |    iterations           | 30           |
# |    time_elapsed         | 585          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.018811785  |
# |    clip_fraction        | 0.187        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.872       |
# |    explained_variance   | -0.016571283 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.599        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.035       |
# |    value_loss           | 1.25         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 31          |
# |    time_elapsed         | 603         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.017099798 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | 0.012965798 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.552       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 1.36        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 32          |
# |    time_elapsed         | 622         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.017407808 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.01576215  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.518       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0328     |
# |    value_loss           | 1.44        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 33          |
# |    time_elapsed         | 641         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.019526381 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | -0.1280266  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.713       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.034      |
# |    value_loss           | 1.59        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 34          |
# |    time_elapsed         | 659         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.016981862 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | -0.02619791 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.631       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0317     |
# |    value_loss           | 1.46        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 422           |
# |    iterations           | 35            |
# |    time_elapsed         | 678           |
# |    total_timesteps      | 286720        |
# | train/                  |               |
# |    approx_kl            | 0.0167924     |
# |    clip_fraction        | 0.156         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.864        |
# |    explained_variance   | -0.0003787279 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.616         |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.033        |
# |    value_loss           | 1.56          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 36          |
# |    time_elapsed         | 696         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.016317252 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | -0.03039062 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.42        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0319     |
# |    value_loss           | 1.32        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 37           |
# |    time_elapsed         | 715          |
# |    total_timesteps      | 303104       |
# | train/                  |              |
# |    approx_kl            | 0.017322524  |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.858       |
# |    explained_variance   | -0.046242118 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.593        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0319      |
# |    value_loss           | 1.45         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 38           |
# |    time_elapsed         | 733          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.017439108  |
# |    clip_fraction        | 0.18         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.857       |
# |    explained_variance   | -0.020925641 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.684        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0344      |
# |    value_loss           | 1.72         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 39          |
# |    time_elapsed         | 752         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.019323703 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | -0.06931257 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.676       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0347     |
# |    value_loss           | 1.51        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 40          |
# |    time_elapsed         | 770         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.019149207 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.848      |
# |    explained_variance   | -0.07471025 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.5         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0324     |
# |    value_loss           | 1.43        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 41           |
# |    time_elapsed         | 788          |
# |    total_timesteps      | 335872       |
# | train/                  |              |
# |    approx_kl            | 0.020077292  |
# |    clip_fraction        | 0.191        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.851       |
# |    explained_variance   | -0.053553224 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.619        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.033       |
# |    value_loss           | 1.35         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 42          |
# |    time_elapsed         | 807         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.022412844 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | -0.12216985 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.616       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 1.36        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 43           |
# |    time_elapsed         | 826          |
# |    total_timesteps      | 352256       |
# | train/                  |              |
# |    approx_kl            | 0.017008318  |
# |    clip_fraction        | 0.175        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.836       |
# |    explained_variance   | -0.037735343 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.763        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.031       |
# |    value_loss           | 1.8          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 44          |
# |    time_elapsed         | 846         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.021048646 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | -0.07438421 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.813       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 1.64        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 45           |
# |    time_elapsed         | 865          |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.022764534  |
# |    clip_fraction        | 0.21         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | -0.069630265 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.646        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0357      |
# |    value_loss           | 1.7          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 425          |
# |    iterations           | 46           |
# |    time_elapsed         | 884          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.022648714  |
# |    clip_fraction        | 0.205        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | -0.031406045 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.735        |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0342      |
# |    value_loss           | 1.82         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 47          |
# |    time_elapsed         | 902         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.023142228 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | -0.07387936 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.531       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 1.43        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 48          |
# |    time_elapsed         | 920         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.0224212   |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | -0.08129394 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.73        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0329     |
# |    value_loss           | 1.55        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 49          |
# |    time_elapsed         | 939         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.022799911 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.832      |
# |    explained_variance   | -0.04562998 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.656       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0352     |
# |    value_loss           | 1.45        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 50          |
# |    time_elapsed         | 957         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.022958655 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.831      |
# |    explained_variance   | -0.08807385 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.79        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0359     |
# |    value_loss           | 1.56        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 51           |
# |    time_elapsed         | 976          |
# |    total_timesteps      | 417792       |
# | train/                  |              |
# |    approx_kl            | 0.023242822  |
# |    clip_fraction        | 0.193        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.823       |
# |    explained_variance   | -0.049223423 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.561        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0325      |
# |    value_loss           | 1.55         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 52           |
# |    time_elapsed         | 995          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.019550413  |
# |    clip_fraction        | 0.18         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.83        |
# |    explained_variance   | -0.053171158 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.544        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0319      |
# |    value_loss           | 1.47         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 53           |
# |    time_elapsed         | 1015         |
# |    total_timesteps      | 434176       |
# | train/                  |              |
# |    approx_kl            | 0.02049094   |
# |    clip_fraction        | 0.18         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.83        |
# |    explained_variance   | -0.018850923 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.793        |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0348      |
# |    value_loss           | 1.73         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 54           |
# |    time_elapsed         | 1033         |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.021075616  |
# |    clip_fraction        | 0.203        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | -0.051208854 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.625        |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0319      |
# |    value_loss           | 1.53         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 55          |
# |    time_elapsed         | 1051        |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.02018331  |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.819      |
# |    explained_variance   | -0.07070696 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.849       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0344     |
# |    value_loss           | 1.64        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 56          |
# |    time_elapsed         | 1071        |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.022992635 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.82       |
# |    explained_variance   | -0.10743165 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.574       |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 1.33        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 428          |
# |    iterations           | 57           |
# |    time_elapsed         | 1090         |
# |    total_timesteps      | 466944       |
# | train/                  |              |
# |    approx_kl            | 0.022669856  |
# |    clip_fraction        | 0.187        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.817       |
# |    explained_variance   | -0.010868311 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.654        |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.0346      |
# |    value_loss           | 1.71         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 58          |
# |    time_elapsed         | 1108        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.02417574  |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.819      |
# |    explained_variance   | -0.13146472 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.744       |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0329     |
# |    value_loss           | 1.51        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 428          |
# |    iterations           | 59           |
# |    time_elapsed         | 1127         |
# |    total_timesteps      | 483328       |
# | train/                  |              |
# |    approx_kl            | 0.01834141   |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.815       |
# |    explained_variance   | -0.022237182 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04         |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0325      |
# |    value_loss           | 1.84         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 60          |
# |    time_elapsed         | 1146        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.02253293  |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | -0.06760979 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.688       |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0348     |
# |    value_loss           | 1.39        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 428           |
# |    iterations           | 61            |
# |    time_elapsed         | 1165          |
# |    total_timesteps      | 499712        |
# | train/                  |               |
# |    approx_kl            | 0.021807406   |
# |    clip_fraction        | 0.19          |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.82         |
# |    explained_variance   | -0.0152493715 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.803         |
# |    n_updates            | 600           |
# |    policy_gradient_loss | -0.0332       |
# |    value_loss           | 1.45          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 62          |
# |    time_elapsed         | 1184        |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.022600118 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.815      |
# |    explained_variance   | 0.049045563 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.57        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0314     |
# |    value_loss           | 1.53        |
# -----------------------------------------
# Saved model -> models\multiasset\ppo_multiasset.zip
# -------------------------------------------------------------------
# TypeError                         Traceback (most recent call last)
# Cell In[10], line 9
#       6 model, vec_env = train_and_save(datasets, asset_map, embeddings, MODEL_DIR, TOTAL_TIMESTEPS, N_ENVS)
#       8 # Evaluate
# ----> 9 metrics = evaluate_model(MODEL_FILE, datasets, n_episodes=10, window=WINDOW)
#      10 print("Done. Metrics:", metrics)
#
# Cell In[9], line 8, in evaluate_model(model_path, datasets, n_episodes, window)
#       5 emb_dummy = np.zeros((len(datasets), EMBED_DIM), dtype=np.float32)
#       6 asset_map = {s: i for i, s in enumerate(datasets.keys())}
# ----> 8 env = MultiAssetEnv(
#       9     datasets=datasets,
#      10     asset_map=asset_map,
#      11     embeddings=emb_dummy,
#      12     window=window
#      13 )
#      15 rewards = []
#      17 for ep in range(n_episodes):
#
# TypeError: MultiAssetEnv.__init__() got an unexpected keyword argument 'asset_map'

# %%
# Visualize a single rollout and save animation/mp4
model = PPO.load(MODEL_FILE)
env = MultiAssetEnv(datasets, asset_map, embeddings, window=WINDOW)
obs, _ = env.reset()
done = False
while not done:
    action, _ = model.predict(obs, deterministic=True)
    act = int(action) if isinstance(action,(np.integer,int)) else int(action[0])
    obs, reward, done, truncated, info = env.step(act)

# Save animation to file
out_path = os.path.join(MODEL_DIR, "last_run.mp4")
env.render(animate=True, save_path=out_path, fps=12)

# %%
# Visualize a single rollout and save animation/mp4
model = PPO.load(MODEL_FILE)
env = MultiAssetEnv(datasets, asset_map, embeddings, window=WINDOW)

obs, _ = env.reset()
done = False

while not done:
    action, _ = model.predict(obs, deterministic=True)
    action = int(action) if isinstance(action, (int, np.integer)) else int(action[0])
    obs, reward, done, truncated, info = env.step(action)

# Save the animated trading chart
animation_path = os.path.join(MODEL_DIR, "sample_rollout.mp4")
env.render(animate=True, save_path=animation_path)

print("Saved rollout animation:", animation_path)

# %%
# Export summary of training session
summary = {
    "window": WINDOW,
    "train_episodes": TRAIN_EPISODES,
    "total_timesteps": TOTAL_TIMESTEPS,
    "n_assets": len(datasets),
    "embedding_dimension": EMBED_DIM,
    "model_file": MODEL_FILE,
    "vec_file": VEC_FILE,
    "metrics_file": METRICS_FILE,
    "rollout_animation": os.path.join(MODEL_DIR, "sample_rollout.mp4"),
    "timestamp": datetime.utcnow().isoformat()
}

SUMMARY_FILE = os.path.join(MODEL_DIR, "run_summary.json")
with open(SUMMARY_FILE, "w") as f:
    json.dump(summary, f, indent=2)

print("=== TRAINING COMPLETE ===")
print("Summary saved to:", SUMMARY_FILE)
print("\nArtifacts generated:")
for k, v in summary.items():
    print(f"{k}: {v}")
